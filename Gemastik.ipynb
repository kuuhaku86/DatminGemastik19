# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
filepath = "data.xls"
electricity_data = pd.read_excel(filepath)

# %%
electricity_data.head()
# Out:
#   Country Code                      Region          IncomeGroup  1960  1961  \
# 0          AGO          Sub-Saharan Africa  Lower middle income   NaN   NaN
# 1          ALB       Europe & Central Asia  Upper middle income   NaN   NaN
# 2          ARB                         NaN                  NaN   NaN   NaN
# 3          ARE  Middle East & North Africa          High income   NaN   NaN
# 4          ARG   Latin America & Caribbean  Upper middle income   NaN   NaN
#
#    1962  1963  1964  1965  1966  ...          2005          2006  \
# 0   NaN   NaN   NaN   NaN   NaN  ...    109.295230    144.715351
# 1   NaN   NaN   NaN   NaN   NaN  ...   1722.072850   1218.360146
# 2   NaN   NaN   NaN   NaN   NaN  ...   1840.432063   1940.406475
# 3   NaN   NaN   NaN   NaN   NaN  ...  12279.912166  11693.389689
# 4   NaN   NaN   NaN   NaN   NaN  ...   2408.432525   2374.097471
#
#            2007          2008          2009          2010          2011  \
# 0    133.267239    172.384914    189.257654    206.454411    207.013343
# 1   1213.124369   1617.744156   1835.684072   1943.343354   2205.703920
# 2   1995.377548   2061.822740   2119.801726   2296.780903   2332.708771
# 3  11451.913634  11294.188141  10618.801289  10609.956412  10287.056445
# 4   2455.656576   2772.843222   2730.123232   2877.652653   2929.075029
#
#            2012          2013          2014
# 0    219.253430    280.214547    312.228825
# 1   2118.327776   2533.252829   2309.366503
# 2   2371.597009   2427.835367   2501.479657
# 3  10416.014884  10724.501544  11088.350286
# 4   3000.603523   2967.376558   3074.702071
#
# [5 rows x 58 columns]

# %%
electricity_data.shape
# Out:
# (184, 58)

# %%
electricity_data.columns
# Out:
# Index(['Country Code', 'Region', 'IncomeGroup', '1960', '1961', '1962', '1963',
#        '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972',
#        '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981',
#        '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990',
#        '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999',
#        '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014'],
#       dtype='object')

# %%
electricity_data.dtypes
# Out:
# Country Code     object
# Region           object
# IncomeGroup      object
# 1960            float64
# 1961            float64
# 1962            float64
# 1963            float64
# 1964            float64
# 1965            float64
# 1966            float64
# 1967            float64
# 1968            float64
# 1969            float64
# 1970            float64
# 1971            float64
# 1972            float64
# 1973            float64
# 1974            float64
# 1975            float64
# 1976            float64
# 1977            float64
# 1978            float64
# 1979            float64
# 1980            float64
# 1981            float64
# 1982            float64
# 1983            float64
# 1984            float64
# 1985            float64
# 1986            float64
# 1987            float64
# 1988            float64
# 1989            float64
# 1990            float64
# 1991            float64
# 1992            float64
# 1993            float64
# 1994            float64
# 1995            float64
# 1996            float64
# 1997            float64
# 1998            float64
# 1999            float64
# 2000            float64
# 2001            float64
# 2002            float64
# 2003            float64
# 2004            float64
# 2005            float64
# 2006            float64
# 2007            float64
# 2008            float64
# 2009            float64
# 2010            float64
# 2011            float64
# 2012            float64
# 2013            float64
# 2014            float64
# dtype: object

# %%
plt.figure(figsize=(20,6))
sns.countplot(electricity_data['IncomeGroup'])

# %%
plt.figure(figsize=(20,6))
sns.countplot(electricity_data['Region'])

# %%
sns.catplot(x='Region', y='2014', kind="box",  data=electricity_data, height=6,aspect=2.5)
sns.stripplot(x='Region', y='2014', data=electricity_data, alpha=0.3,jitter=0.2,color='k')

# %%
sns.catplot(x='IncomeGroup', y='2014', kind="box",  data=electricity_data,height=6,aspect=2.5)
sns.stripplot(x='IncomeGroup', y='2014', data=electricity_data, alpha=0.3,jitter=0.2,color='k')

# %%
numerical_features = electricity_data.select_dtypes(include='float64')
numerical_features = numerical_features.columns
for i in range(3,14):
    plt.figure(figsize=(35,6))
    plt.plot(numerical_features,electricity_data.loc[i,numerical_features])
    plt.show()

# %%
electricity_data.describe()
# Out:
#               1960         1961         1962         1963          1964  \
# count    32.000000    32.000000    32.000000    32.000000     32.000000
# mean   2110.306406  2234.860212  2390.677348  2577.136097   2808.854190
# std    1705.697598  1795.235577  1946.048690  2097.923624   2351.595520
# min       0.000000     0.000000     0.000000     0.000000      0.000000
# 25%    1060.967012  1155.907748  1274.349817  1440.030723   1555.434228
# 50%    1700.712716  1782.819312  1898.728637  2020.643356   2147.945740
# 75%    2496.474698  2680.400806  2809.264465  3021.275001   3158.237433
# max    7681.140521  8404.620755  9390.978307  9658.705203  10553.444067
#
#                1965          1966          1967          1968          1969  \
# count     33.000000     33.000000     33.000000     33.000000     33.000000
# mean    2923.315242   3078.743906   3222.136289   3438.516693   3703.139246
# std     2486.013287   2564.757269   2642.584590   2797.347011   2882.257047
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%     1446.739592   1573.202079   1693.254317   1823.398750   1934.814463
# 50%     2194.206061   2300.499798   2362.908943   2596.177718   2830.593969
# 75%     3330.183880   3425.803087   3558.069801   3852.192111   4071.556095
# max    11416.352955  11655.971257  12256.975024  13494.874605  13230.217374
#
#        ...          2005          2006          2007          2008  \
# count  ...    183.000000    183.000000    183.000000    183.000000
# mean   ...   3657.561452   3741.535948   3812.869010   3876.288236
# std    ...   4626.860534   4729.528324   4904.482100   5382.071099
# min    ...     33.531417     34.855841     25.486218     23.738983
# 25%    ...    605.383760    666.691803    690.720143    641.976120
# 50%    ...   2001.924858   2072.362647   2073.153050   2046.694449
# 75%    ...   5038.322085   5231.330845   5412.775649   5439.660713
# max    ...  27988.029683  31328.386804  36852.544886  50063.954331
#
#                2009          2010          2011          2012          2013  \
# count    183.000000    183.000000    183.000000    183.000000    183.000000
# mean    3768.774493   3927.710609   3929.310870   3945.509963   3962.339076
# std     5291.242433   5417.932005   5369.389742   5408.579788   5461.678965
# min       35.925530     24.524284     31.286137     41.429170     42.974259
# 25%      613.466819    641.329129    681.439152    728.223720    755.629569
# 50%     2100.064940   2307.804679   2332.708771   2371.597009   2498.340357
# 75%     5143.376644   5376.477813   5430.628627   5289.197648   5180.825472
# max    51259.187627  51439.908691  52373.877009  53202.833660  54799.174708
#
#                2014
# count    183.000000
# mean    3962.885529
# std     5411.678989
# min       39.055805
# 25%      782.143908
# 50%     2538.796380
# 75%     5096.067107
# max    53832.479092
#
# [8 rows x 55 columns]

# %%
print(electricity_data.isnull().sum())
from sklearn.preprocessing import Imputer
electricity_data = electricity_data.drop(['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970'],axis=1)
numerical_features = electricity_data.select_dtypes(include='float64')
numerical_features = numerical_features.columns
imputer = Imputer(missing_values = 'NaN',strategy='median',axis=0)
imputer = imputer.fit(electricity_data[numerical_features])
electricity_data[numerical_features] = imputer.transform(electricity_data[numerical_features])
electricity_data.head()
# Out:
# Country Code      0
# Region           42
# IncomeGroup      42
# 1960            152
# 1961            152
# 1962            152
# 1963            152
# 1964            152
# 1965            151
# 1966            151
# 1967            151
# 1968            151
# 1969            151
# 1970            151
# 1971             35
# 1972             35
# 1973             35
# 1974             35
# 1975             35
# 1976             35
# 1977             35
# 1978             35
# 1979             35
# 1980             35
# 1981             34
# 1982             34
# 1983             34
# 1984             34
# 1985             33
# 1986             33
# 1987             33
# 1988             33
# 1989             33
# 1990             10
# 1991              9
# 1992              9
# 1993              9
# 1994              9
# 1995              7
# 1996              7
# 1997              7
# 1998              7
# 1999              7
# 2000              2
# 2001              2
# 2002              2
# 2003              2
# 2004              2
# 2005              1
# 2006              1
# 2007              1
# 2008              1
# 2009              1
# 2010              1
# 2011              1
# 2012              1
# 2013              1
# 2014              1
# dtype: int64
# C:\Users\Acer-PC\.conda\envs\DataScience\lib\site-packages\sklearn\utils\deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
#   Country Code                      Region          IncomeGroup        1971  \
# 0          AGO          Sub-Saharan Africa  Lower middle income   92.041140
# 1          ALB       Europe & Central Asia  Upper middle income  532.028432
# 2          ARB                         NaN                  NaN  196.208927
# 3          ARE  Middle East & North Africa          High income  681.152265
# 4          ARG   Latin America & Caribbean  Upper middle income  874.459352
#
#           1972         1973         1974         1975         1976  \
# 0   100.503285   113.591552   136.362695   139.379271    60.306265
# 1   568.403202   593.446746   591.032643   739.345093   908.674547
# 2   210.933920   230.225846   254.632324   282.106110   325.267155
# 3  1314.302634  1700.352741  1876.132472  2321.717451  2829.499531
# 4   925.316922   962.266125   993.233055  1011.993609  1032.489220
#
#           1977  ...          2005          2006          2007          2008  \
# 0    58.271229  ...    109.295230    144.715351    133.267239    172.384914
# 1  1067.814156  ...   1722.072850   1218.360146   1213.124369   1617.744156
# 2   369.282070  ...   1840.432063   1940.406475   1995.377548   2061.822740
# 3  3737.026480  ...  12279.912166  11693.389689  11451.913634  11294.188141
# 4  1081.751227  ...   2408.432525   2374.097471   2455.656576   2772.843222
#
#            2009          2010          2011          2012          2013  \
# 0    189.257654    206.454411    207.013343    219.253430    280.214547
# 1   1835.684072   1943.343354   2205.703920   2118.327776   2533.252829
# 2   2119.801726   2296.780903   2332.708771   2371.597009   2427.835367
# 3  10618.801289  10609.956412  10287.056445  10416.014884  10724.501544
# 4   2730.123232   2877.652653   2929.075029   3000.603523   2967.376558
#
#            2014
# 0    312.228825
# 1   2309.366503
# 2   2501.479657
# 3  11088.350286
# 4   3074.702071
#
# [5 rows x 47 columns]

# %%
electricity_data = electricity_data[electricity_data['IncomeGroup'].notnull()]

# %%
electricity_data.describe()
# Out:
#                1971          1972          1973          1974          1975  \
# count    142.000000    142.000000    142.000000    142.000000    142.000000
# mean    1246.374715   1332.721935   1434.399872   1483.175335   1497.968976
# std     2163.750009   2262.924750   2424.063818   2517.721397   2442.093381
# min        6.004553      7.549785      5.757766      7.158491      6.631710
# 25%      163.173973    174.293057    180.863416    202.535853    212.399804
# 50%      320.782411    344.024981    397.089430    426.900991    454.343222
# 75%     1272.920267   1368.508879   1584.461080   1556.999180   1649.251651
# max    14084.409610  14488.416488  15541.790006  16286.774909  16313.924068
#
#                1976          1977          1978          1979          1980  \
# count    142.000000    142.000000    142.000000    142.000000    142.000000
# mean    1600.439138   1670.119624   1763.429230   1896.329538   1952.694736
# std     2577.565030   2605.333817   2723.424998   2896.810654   2962.657351
# min        8.965360      9.837092     10.524378     11.582805     12.386456
# 25%      242.079864    262.767418    289.359409    318.609648    357.292814
# 50%      489.868491    530.870553    578.740782    685.019822    665.209943
# 75%     1766.330813   1872.503279   2063.403423   2136.246512   2224.729755
# max    16913.420060  16515.363431  17314.781119  18862.290814  18725.676886
#
#        ...          2005          2006          2007          2008  \
# count  ...    142.000000    142.000000    142.000000    142.000000
# mean   ...   3962.858996   4051.416463   4124.822999   4202.212178
# std    ...   4953.155658   5078.555353   5285.780575   5853.274922
# min    ...     33.531417     34.855841     25.486218     23.738983
# 25%    ...    765.209634    793.190332    751.923150    777.662275
# 50%    ...   2065.618825   2200.134062   2280.820210   2369.570425
# 75%    ...   5681.212625   5860.435416   5881.593470   5863.576443
# max    ...  27988.029683  31328.386804  36852.544886  50063.954331
#
#                2009          2010          2011          2012          2013  \
# count    142.000000    142.000000    142.000000    142.000000    142.000000
# mean    4083.689417   4245.856624   4234.231773   4250.020152   4261.208012
# std     5773.203403   5907.791472   5859.449392   5911.050244   5976.085838
# min       35.925530     24.524284     31.286137     41.429170     42.974259
# 25%      770.810535    796.232860    839.516065    886.556281    900.815553
# 50%     2334.073558   2436.839776   2534.918415   2465.525996   2537.037074
# 75%     5639.317373   5655.911863   5642.997963   5513.485919   5409.575624
# max    51259.187627  51439.908691  52373.877009  53202.833660  54799.174708
#
#                2014
# count    142.000000
# mean    4258.096299
# std     5921.770990
# min       39.055805
# 25%      912.600085
# 50%     2604.130643
# 75%     5539.153100
# max    53832.479092
#
# [8 rows x 44 columns]

# %%
print(electricity_data.isnull().sum())
print(electricity_data.shape)
# Out:
# Country Code    0
# Region          0
# IncomeGroup     0
# 1971            0
# 1972            0
# 1973            0
# 1974            0
# 1975            0
# 1976            0
# 1977            0
# 1978            0
# 1979            0
# 1980            0
# 1981            0
# 1982            0
# 1983            0
# 1984            0
# 1985            0
# 1986            0
# 1987            0
# 1988            0
# 1989            0
# 1990            0
# 1991            0
# 1992            0
# 1993            0
# 1994            0
# 1995            0
# 1996            0
# 1997            0
# 1998            0
# 1999            0
# 2000            0
# 2001            0
# 2002            0
# 2003            0
# 2004            0
# 2005            0
# 2006            0
# 2007            0
# 2008            0
# 2009            0
# 2010            0
# 2011            0
# 2012            0
# 2013            0
# 2014            0
# dtype: int64
# (142, 47)

# %%
for i in range(3,14):
    plt.figure(figsize=(35,6))
    plt.plot(numerical_features,electricity_data.loc[i,numerical_features])
    plt.show()

# %%
import numpy as np
y = electricity_data['2014']
selected_features = np.concatenate((numerical_features,['IncomeGroup']),axis=0)
X = electricity_data[selected_features]
X.head()
# Out:
#          1971         1972         1973         1974         1975  \
# 0   92.041140   100.503285   113.591552   136.362695   139.379271
# 1  532.028432   568.403202   593.446746   591.032643   739.345093
# 3  681.152265  1314.302634  1700.352741  1876.132472  2321.717451
# 4  874.459352   925.316922   962.266125   993.233055  1011.993609
# 5  320.782411   344.024981   397.089430   426.900991   454.343222
#
#           1976         1977         1978         1979         1980  ...  \
# 0    60.306265    58.271229    56.349186    58.574842    60.662087  ...
# 1   908.674547  1067.814156  1098.483166  1065.767398  1142.965355  ...
# 3  2829.499531  3737.026480  4190.265084  4982.028422  5752.769225  ...
# 4  1032.489220  1081.751227  1093.416674  1217.172880  1243.631466  ...
# 5   489.868491   530.870553   578.740782   685.019822   665.209943  ...
#
#            2006          2007          2008          2009          2010  \
# 0    144.715351    133.267239    172.384914    189.257654    206.454411
# 1   1218.360146   1213.124369   1617.744156   1835.684072   1943.343354
# 3  11693.389689  11451.913634  11294.188141  10618.801289  10609.956412
# 4   2374.097471   2455.656576   2772.843222   2730.123232   2877.652653
# 5   1639.789244   1773.159682   1669.407742   1661.304418   1726.259758
#
#            2011          2012          2013          2014          IncomeGroup
# 0    207.013343    219.253430    280.214547    312.228825  Lower middle income
# 1   2205.703920   2118.327776   2533.252829   2309.366503  Upper middle income
# 3  10287.056445  10416.014884  10724.501544  11088.350286          High income
# 4   2929.075029   3000.603523   2967.376558   3074.702071  Upper middle income
# 5   1807.033316   1892.013429   1931.264115   1961.610395  Upper middle income
#
# [5 rows x 45 columns]

# %%
y.head()
# Out:
# 0      312.228825
# 1     2309.366503
# 3    11088.350286
# 4     3074.702071
# 5     1961.610395
# Name: 2014, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_valid, y_train, y_valid = train_test_split(X,y,random_state=1)

# %%
from sklearn.preprocessing import OneHotEncoder

OH_encoder = OneHotEncoder(handle_unknown='ignore', sparse=False)
OH_cols_train = pd.DataFrame(OH_encoder.fit_transform(X_train[['IncomeGroup']]))
OH_cols_valid = pd.DataFrame(OH_encoder.transform(X_valid[['IncomeGroup']]))

OH_cols_train.index = X_train.index
OH_cols_valid.index = X_valid.index

num_X_train = X_train.drop(['IncomeGroup'], axis=1)
num_X_valid = X_valid.drop(['IncomeGroup'], axis=1)

X_train = pd.concat([num_X_train, OH_cols_train], axis=1)
X_valid = pd.concat([num_X_valid, OH_cols_valid], axis=1)
print(X_train.head())
print(X_train.shape)
print(X_valid.shape)
print(y_train.head())
print(y_train.shape)
print(y_valid.shape)
# Out:
#            1971        1972        1973        1974        1975        1976  \
# 19   320.782411  344.024981  397.089430  426.900991  454.343222  489.868491
# 5    320.782411  344.024981  397.089430  426.900991  454.343222  489.868491
# 143  323.737269  358.049545  414.784258  502.372092  534.403092  727.034961
# 48   320.782411  344.024981  397.089430  426.900991  454.343222  489.868491
# 39   133.873489  142.875928  158.754155  170.660458  195.692277  220.065773
#
#            1977         1978         1979         1980  ...         2009  \
# 19   530.870553   578.740782   685.019822   665.209943  ...  1739.955710
# 5    530.870553   578.740782   685.019822   665.209943  ...  1661.304418
# 143  838.481245  1113.007114  1612.947882  1971.113585  ...  7477.083531
# 48   530.870553   578.740782   685.019822   665.209943  ...    83.335470
# 39   233.124176   278.970600   314.567685   330.304373  ...   866.307327
#
#             2010         2011         2012         2013         2014    0  \
# 19   1561.064966  1503.422146  1756.268904  2126.508337  1815.558069  0.0
# 5    1726.259758  1807.033316  1892.013429  1931.264115  1961.610395  0.0
# 143  7974.739202  8015.123983  8502.775167  8784.621641  9401.366769  1.0
# 48     85.792644    89.297604  2371.597009  2498.340357  2538.796380  0.0
# 39   1016.636669  1123.332731  1237.966507  1278.915343  1362.871919  0.0
#
#        1    2    3
# 19   0.0  0.0  1.0
# 5    0.0  0.0  1.0
# 143  0.0  0.0  0.0
# 48   1.0  0.0  0.0
# 39   0.0  0.0  1.0
#
# [5 rows x 48 columns]
# (106, 48)
# (36, 48)
# 19     1815.558069
# 5      1961.610395
# 143    9401.366769
# 48     2538.796380
# 39     1362.871919
# Name: 2014, dtype: float64
# (106,)
# (36,)

# %%
from keras.datasets import imdb
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers.embeddings import Embedding
from keras.preprocessing import sequence
from keras.layers import Flatten
from sklearn.metrics import mean_squared_error
# Out:
# Using TensorFlow backend.

# %%
#vanilla LSTM
X_train, y_train = np.array(X_train), np.array(y_train)
X_train_1 = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_valid, y_valid = np.array(X_valid), np.array(y_valid)
X_valid_1 = np.reshape(X_valid, (X_valid.shape[0], X_valid.shape[1], 1))

model = Sequential()
model.add(LSTM(50, activation='relu', input_shape=(48, 1)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
model.fit(X_train_1,y_train,epochs=200, verbose=0)

y_res = model.predict(X_valid_1,verbose=0)
y_res = y_res[:,0]
print('RMSE = ',np.sqrt(mean_squared_error(y_valid,y_res)))
y_res = pd.DataFrame(data=y_res)
y_valid_1 = pd.DataFrame(data=y_valid)
y_res.columns = ['forecast']
y_valid_1.columns = ['actual']
print(y_res.describe(),'\n',y_valid_1.describe())
ax = plt.gca()
y_res.plot(kind='line',y='forecast',ax=ax)
y_valid_1.plot(kind='line',y='actual',ax=ax)
plt.show()
# Out:
# RMSE =  2728.261675313126
#            forecast
# count     36.000000
# mean    5236.027344
# std     6313.709961
# min       80.305069
# 25%     1166.806213
# 50%     2435.357422
# 75%     8048.509644
# max    25653.158203
#               actual
# count     36.000000
# mean    4085.024939
# std     4420.549958
# min       51.195008
# 25%      965.006324
# 50%     2383.460472
# 75%     5865.441455
# max    15590.599906

# %%
#stacked LSTM
model = Sequential()
model.add(LSTM(50, activation='relu', return_sequences=True, input_shape=(48, 1)))
model.add(LSTM(50, activation='relu'))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

model.fit(X_train_1, y_train, epochs=200, verbose=0)
y_res = model.predict(X_valid_1, verbose=0)
y_res = y_res[:,0]
print('RMSE = ',np.sqrt(mean_squared_error(y_valid,y_res)))
y_res = pd.DataFrame(data=y_res)
y_valid_1 = pd.DataFrame(data=y_valid)
y_res.columns = ['forecast']
y_valid_1.columns = ['actual']
print(y_res.describe(),'\n',y_valid_1.describe())
ax = plt.gca()
y_res.plot(kind='line',y='forecast',ax=ax)
y_valid_1.plot(kind='line',y='actual',ax=ax)
plt.show()
# Out:
# RMSE =  3139.803420187979
#            forecast
# count     36.000000
# mean    3878.784180
# std     6068.859863
# min     -143.686844
# 25%      498.714790
# 50%     1421.389221
# 75%     3405.019653
# max    26319.914062
#               actual
# count     36.000000
# mean    4085.024939
# std     4420.549958
# min       51.195008
# 25%      965.006324
# 50%     2383.460472
# 75%     5865.441455
# max    15590.599906

# %%
#bidirectional LSTM
from keras.layers import Bidirectional
model = Sequential()
model.add(Bidirectional(LSTM(50, activation='relu'), input_shape=(48, 1)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

model.fit(X_train_1, y_train, epochs=200, verbose=0)
y_res = model.predict(X_valid_1, verbose=0)
y_res = y_res[:,0]
print('RMSE = ',np.sqrt(mean_squared_error(y_valid,y_res)))
y_res = pd.DataFrame(data=y_res)
y_valid_1 = pd.DataFrame(data=y_valid)
y_res.columns = ['forecast']
y_valid_1.columns = ['actual']
print(y_res.describe(),'\n',y_valid_1.describe())
ax = plt.gca()
y_res.plot(kind='line',y='forecast',ax=ax)
y_valid_1.plot(kind='line',y='actual',ax=ax)
plt.show()
# Out:
# RMSE =  2696.591114513536
#           forecast
# count    36.000000
# mean   2247.456543
# std    2599.647217
# min    -301.106689
# 25%     388.513397
# 50%    1053.304443
# 75%    3238.677307
# max    8502.433594
#               actual
# count     36.000000
# mean    4085.024939
# std     4420.549958
# min       51.195008
# 25%      965.006324
# 50%     2383.460472
# 75%     5865.441455
# max    15590.599906

# %%
#vector output model LSTM
model = Sequential()
model.add(LSTM(100, activation='relu', return_sequences=True, input_shape=(48, 1)))
model.add(LSTM(100, activation='relu'))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

model.fit(X_train_1, y_train, epochs=200, verbose=0)
y_res = model.predict(X_valid_1, verbose=0)
y_res = y_res[:,0]
print('RMSE = ',np.sqrt(mean_squared_error(y_valid,y_res)))
y_res = pd.DataFrame(data=y_res)
y_valid_1 = pd.DataFrame(data=y_valid)
y_res.columns = ['forecast']
y_valid_1.columns = ['actual']
print(y_res.describe(),'\n',y_valid_1.describe())
ax = plt.gca()
y_res.plot(kind='line',y='forecast',ax=ax)
y_valid_1.plot(kind='line',y='actual',ax=ax)
plt.show()
# Out:
# RMSE =  12295.044457425125
#            forecast
# count     36.000000
# mean    5774.377441
# std    14577.902344
# min    -6558.418457
# 25%       47.776711
# 50%     1067.943359
# 75%     4139.705811
# max    74584.179688
#               actual
# count     36.000000
# mean    4085.024939
# std     4420.549958
# min       51.195008
# 25%      965.006324
# 50%     2383.460472
# 75%     5865.441455
# max    15590.599906

# %%
#testing epoch for i in range(21):
for i in range(1,6):
    model = Sequential()
    model.add(Bidirectional(LSTM(50, activation='relu'), input_shape=(48, 1)))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mse')
    model.fit(X_train_1, y_train, epochs=i*200, verbose=0)

    y_res = model.predict(X_valid_1,verbose=0)
    y_res = y_res[:,0]
    print('RMSE = ',np.sqrt(mean_squared_error(y_valid,y_res)),' Epoch = ',i*200)
    y_res = pd.DataFrame(data=y_res)
    y_valid_1 = pd.DataFrame(data=y_valid)
    y_res.columns = ['forecast']
    y_valid_1.columns = ['actual']
    print(y_res.describe(),'\n',y_valid_1.describe())
    ax = plt.gca()
    y_res.plot(kind='line',y='forecast',ax=ax)
    y_valid_1.plot(kind='line',y='actual',ax=ax)
    plt.show()
# Out:
# RMSE =  2729.1312993383212  Epoch =  200
#            forecast
# count     36.000000
# mean    3347.891113
# std     4928.026367
# min    -1077.603027
# 25%      268.014641
# 50%     1384.350403
# 75%     3140.878174
# max    19482.027344
#               actual
# count     36.000000
# mean    4085.024939
# std     4420.549958
# min       51.195008
# 25%      965.006324
# 50%     2383.460472
# 75%     5865.441455
# max    15590.599906
# RMSE =  7814.637703176946  Epoch =  400
#            forecast
# count     36.000000
# mean    6770.211426
# std     9535.901367
# min     -844.555786
# 25%      583.657326
# 50%     1959.440857
# 75%     9392.810303
# max    38626.734375
#               actual
# count     36.000000
# mean    4085.024939
# std     4420.549958
# min       51.195008
# 25%      965.006324
# 50%     2383.460472
# 75%     5865.441455
# max    15590.599906
# RMSE =  1678.2225847670352  Epoch =  600
#            forecast
# count     36.000000
# mean    4812.001465
# std     5619.286133
# min       47.394970
# 25%     1168.449158
# 50%     2571.866821
# 75%     6525.833130
# max    19695.580078
#               actual
# count     36.000000
# mean    4085.024939
# std     4420.549958
# min       51.195008
# 25%      965.006324
# 50%     2383.460472
# 75%     5865.441455
# max    15590.599906
